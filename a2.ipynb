# %%
import threading
import datetime
import random
import time
import csv
import re
import urllib.request
import xml.etree.ElementTree as ET
from urllib.error import HTTPError
import requests
from bs4 import BeautifulSoup as bs

date = datetime.datetime.now()
currDate = '{}/{}/{}'.format(date.day,date.month,date.year)
random.seed(datetime.datetime.now())

# Directories for the BBC news webpages I'm interested in
BBCArticleURLs = ('world','uk','business','politics','health',
'education','science_and_environment','technology','entertainment_and_arts',
'world/africa','world/asia','world/europe','world/latin_america','world/middle_east',
'world/us_and_canada','england','northern_ireland','scotland','wales')

def getArticles(dir, website):
    try:
        if website == 'BBC':
            tree = ET.parse(source=urllib.request.urlopen('http://feeds.bbci.co.uk/news/'+dir+'/rss.xml'))
        else:
            return None
    except HTTPError as err:
        print(err)
        return None
    except ET.ParseError as err:
        return None
    else:
        root = tree.getroot()
        allArticles = []
        for item in root.iter('item'):
            article = {}
            for elem in item:
                if elem.tag == 'title':
                    article['title'] = elem.text.strip()
                elif elem.tag == 'link':
                    article['link'] = elem.text.strip()
                elif elem.tag == 'description':
                    article['description'] = elem.text.strip()
                elif elem.tag == 'pubDate':
                    article['pubDate'] = elem.text.strip()
                elif website == 'BBC' and elem.tag.endswith('creator'):
                    article['author'] = elem.text.strip()
            allArticles.append(article)
        return allArticles

def extract_data(url):
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')

    articles = soup.find_all('article')
    article_data = []
    for idx, article in enumerate(articles):
        title = article.find('h2').text.strip() if article.find('h2') else None
        description = article.find('p', class_='story__excerpt').text.strip() if article.find('p', class_='story__excerpt') else None
        time = article.find('time').text.strip() if article.find('time') else None
        article_data.append({'id': idx+1, 'title': title, 'description': description, 'time': time, 'source': url})

    return article_data

def preprocess(text):
    clean_text = re.sub('<.*?>', '', text)
    clean_text = re.sub('[^a-zA-Z]', ' ', clean_text)
    clean_text = clean_text.lower()
    clean_text = re.sub(' +', ' ', clean_text)
    return clean_text

def clean_data(data):
    cleaned_data = []
    for article in data:
        article['title'] = preprocess(article['title']) if article.get('title') else None
        article['description'] = preprocess(article['description']) if article.get('description') else None
        cleaned_data.append(article)
    return cleaned_data

def save_to_csv(file_name, articles):
    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['id', 'title', 'description', 'time', 'source']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for article in articles:
            writer.writerow(article)

def writeCSV(articleList, dir, invalid, website):
    if invalid:
        with open('errorLog.csv', 'a', encoding="utf-8") as file:
            fields = ['date', 'website', 'dir', 'articleTitle']
            writeObj = csv.DictWriter(file, fieldnames=fields,lineterminator='\n')

            for article in articleList:
                writeObj.writerow({
                    'date': currDate,
                    'website': website,
                    'dir': dir,
                    'articleTitle': article['title'],
                    'author': article.get('author', ''),
                    'description': article.get('description', ''),
                    'pubDate': article.get('pubDate', '')
                })
    else:
        if website == 'BBC':
            with open('BBCinfoXML.csv', 'a', encoding="utf-8") as file:
                fields = ['date', 'dir', 'articleTitle', 'author', 'description', 'pubDate']
                writeObj = csv.DictWriter(file, fieldnames=fields,lineterminator='\n')

                for article in articleList:
                    writeObj.writerow({
                        'date': currDate,
                        'dir': dir,
                        'articleTitle': article['title'],
                        'author': article.get('author', ''),
                        'description': article.get('description', ''),
                        'pubDate': article.get('pubDate', '')
                    })

def scrape(dir, website):
    allArticles = getArticles(dir, website)
    if allArticles != None:
        writeCSV(allArticles, dir, 0, website)
        print('Downloaded articles from section: {} - {}'.format(website, dir))
    else:
        badscrapeMsg = 'Error could not scrape from section: {}'.format(dir)
        badscrape = []
        badscrape.append(badscrapeMsg)
        writeCSV(badscrape, dir, 1, website)
        print('############ Failed to download articles from section: {} ############ '.format(dir))

def BBCControl():
    for target in BBCArticleURLs:
        scrape(target, 'BBC')
        time.sleep(random.random())

def main():
    # URLs of Dawn and BBC
    urls = ['https://www.dawn.com/', 'https://www.bbc.com/']
    filename = "dawn.csv"

    # Extracting data from URLs
    all_data = []
    for url in urls:
        articles = extract_data(url)
        all_data.extend(articles)

    # Cleaning data
    cleaned_data = clean_data(all_data)

    # Saving data to CSV
    save_to_csv(filename, cleaned_data)
    threading.Thread(target=BBCControl).start()

if __name__ == "__main__":
    main()
# Out:
# C:\Users\gladi\AppData\Local\Temp\ipykernel_53648\2251344828.py:15: DeprecationWarning: Seeding based on hashing is deprecated
# since Python 3.9 and will be removed in a subsequent version. The only
# supported seed types are: None, int, float, str, bytes, and bytearray.
#   random.seed(datetime.datetime.now())
# Downloaded articles from section: BBC - world
# Downloaded articles from section: BBC - uk
# Downloaded articles from section: BBC - business
# Downloaded articles from section: BBC - politics
# Downloaded articles from section: BBC - health
# Downloaded articles from section: BBC - education
# Downloaded articles from section: BBC - science_and_environment
# Downloaded articles from section: BBC - technology
# Downloaded articles from section: BBC - entertainment_and_arts
# Downloaded articles from section: BBC - world/africa
# Downloaded articles from section: BBC - world/asia
# Downloaded articles from section: BBC - world/europe
# Downloaded articles from section: BBC - world/latin_america
# Downloaded articles from section: BBC - world/middle_east
# Downloaded articles from section: BBC - world/us_and_canada
# Downloaded articles from section: BBC - england
# Downloaded articles from section: BBC - northern_ireland
# Downloaded articles from section: BBC - scotland

# %%
def transform(dawn_file, bbc_file, output_file):
    combined_data = []
    dawn_id = 0
    bbc_id = 0
    
    # Read data from dawn.csv
    with open(dawn_file, 'r', newline='', encoding='utf-8') as dawn_csv:
        dawn_reader = csv.DictReader(dawn_csv)
        for row in dawn_reader:
            dawn_id += 1
            combined_data.append({'Id': dawn_id, 'title': row['title'], 'source': 'Dawn'})

    # Read data from BBCinfoXML.csv
    with open(bbc_file, 'r', newline='', encoding='utf-8') as bbc_csv:
        bbc_reader = csv.reader(bbc_csv)
        for row in bbc_reader:
            if row:
                bbc_id += 1
                combined_data.append({'Id': dawn_id + bbc_id, 'title': row[2], 'source': 'BBC'})

    # Write the combined data to a new CSV file
    with open(output_file, 'w', newline='', encoding='utf-8') as output_csv:
        fieldnames = ['Id', 'title', 'source']
        writer = csv.DictWriter(output_csv, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(combined_data)

# Usage
transform('dawn.csv', 'BBCinfoXML.csv', 'cleaned.csv')

# %%
# !pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Using cached apache_airflow-2.9.1-py3-none-any.whl.metadata (43 kB)
# Collecting alembic<2.0,>=1.13.1 (from apache-airflow)
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting argcomplete>=1.10 (from apache-airflow)
#   Using cached argcomplete-3.3.0-py3-none-any.whl.metadata (16 kB)
# Collecting asgiref (from apache-airflow)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (23.2.0)
# Collecting blinker>=1.6.2 (from apache-airflow)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting colorlog<5.0,>=4.0.2 (from apache-airflow)
#   Using cached colorlog-4.8.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting configupdater>=3.1.1 (from apache-airflow)
#   Using cached ConfigUpdater-3.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting connexion<3.0,>=2.10.0 (from connexion[flask]<3.0,>=2.10.0->apache-airflow)
#   Using cached connexion-2.14.2-py2.py3-none-any.whl.metadata (28 kB)
# Collecting cron-descriptor>=1.2.24 (from apache-airflow)
#   Using cached cron_descriptor-1.4.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting croniter>=2.0.2 (from apache-airflow)
#   Using cached croniter-2.0.5-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: cryptography>=39.0.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (42.0.7)
# Collecting deprecated>=1.2.13 (from apache-airflow)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dill>=0.2.2 (from apache-airflow)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting flask-caching>=1.5.0 (from apache-airflow)
#   Using cached Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-session<0.6,>=0.4.0 (from apache-airflow)
#   Using cached flask_session-0.5.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting flask-wtf>=0.15 (from apache-airflow)
#   Using cached flask_wtf-1.2.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting flask<2.3,>=2.2 (from apache-airflow)
#   Using cached Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (2024.3.1)
# Collecting google-re2>=1.0 (from apache-airflow)
#   Using cached google_re2-1.1.20240501-1-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting gunicorn>=20.1.0 (from apache-airflow)
#   Using cached gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting httpx (from apache-airflow)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting itsdangerous>=2.0 (from apache-airflow)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.0.0 (from apache-airflow)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonschema>=4.18.0 (from apache-airflow)
#   Using cached jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting lazy-object-proxy (from apache-airflow)
#   Using cached lazy_object_proxy-1.10.0-cp312-cp312-win_amd64.whl.metadata (8.1 kB)
# Collecting linkify-it-py>=2.0.0 (from apache-airflow)
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting lockfile>=0.12.2 (from apache-airflow)
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (3.0.0)
# Collecting markupsafe>=1.1.1 (from apache-airflow)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting marshmallow-oneofschema>=2.0.1 (from apache-airflow)
#   Using cached marshmallow_oneofschema-3.1.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting mdit-py-plugins>=0.3.0 (from apache-airflow)
#   Using cached mdit_py_plugins-0.4.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting methodtools>=0.4.7 (from apache-airflow)
#   Using cached methodtools-0.4.7.tar.gz (3.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting opentelemetry-api>=1.15.0 (from apache-airflow)
#   Using cached opentelemetry_api-1.24.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting opentelemetry-exporter-otlp (from apache-airflow)
#   Using cached opentelemetry_exporter_otlp-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: packaging>=14.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (24.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (0.12.1)
# Collecting pendulum<4.0,>=2.1.2 (from apache-airflow)
#   Using cached pendulum-3.0.0-cp312-none-win_amd64.whl.metadata (7.0 kB)
# Collecting pluggy>=1.0 (from apache-airflow)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (5.9.8)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (2.18.0)
# Collecting pyjwt>=2.0.0 (from apache-airflow)
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-daemon>=3.0.0 (from apache-airflow)
#   Using cached python_daemon-3.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (2.9.0.post0)
# Collecting python-nvd3>=0.15.0 (from apache-airflow)
#   Using cached python_nvd3-0.16.0-py3-none-any.whl
# Collecting python-slugify>=5.0 (from apache-airflow)
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (2.31.0)
# Collecting rfc3339-validator>=0.1.4 (from apache-airflow)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rich-argparse>=1.0.0 (from apache-airflow)
#   Using cached rich_argparse-1.4.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: rich>=12.4.4 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (13.7.1)
# Collecting setproctitle>=1.1.8 (from apache-airflow)
#   Using cached setproctitle-1.3.3-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting sqlalchemy<2.0,>=1.4.36 (from apache-airflow)
#   Using cached SQLAlchemy-1.4.52-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting sqlalchemy-jsonfield>=1.0 (from apache-airflow)
#   Using cached SQLAlchemy_JSONField-1.0.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow) (0.9.0)
# Collecting tenacity!=8.2.0,>=6.2.0 (from apache-airflow)
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting termcolor>=1.1.0 (from apache-airflow)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting unicodecsv>=0.14.1 (from apache-airflow)
#   Using cached unicodecsv-0.14.1-py3-none-any.whl
# Collecting universal-pathlib>=0.2.2 (from apache-airflow)
#   Using cached universal_pathlib-0.2.2-py3-none-any.whl.metadata (25 kB)
# Collecting werkzeug<3,>=2.0 (from apache-airflow)
#   Using cached werkzeug-2.3.8-py3-none-any.whl.metadata (4.1 kB)
# Collecting apache-airflow-providers-common-io (from apache-airflow)
#   Using cached apache_airflow_providers_common_io-1.3.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting apache-airflow-providers-common-sql (from apache-airflow)
#   Using cached apache_airflow_providers_common_sql-1.13.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting apache-airflow-providers-fab>=1.0.2 (from apache-airflow)
#   Using cached apache_airflow_providers_fab-1.1.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting apache-airflow-providers-ftp (from apache-airflow)
#   Using cached apache_airflow_providers_ftp-3.9.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting apache-airflow-providers-http (from apache-airflow)
#   Using cached apache_airflow_providers_http-4.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting apache-airflow-providers-imap (from apache-airflow)
#   Using cached apache_airflow_providers_imap-3.6.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting apache-airflow-providers-smtp (from apache-airflow)
#   Using cached apache_airflow_providers_smtp-1.7.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting apache-airflow-providers-sqlite (from apache-airflow)
#   Using cached apache_airflow_providers_sqlite-3.8.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting Mako (from alembic<2.0,>=1.13.1->apache-airflow)
#   Using cached Mako-1.3.3-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (4.11.0)
# Collecting flask-appbuilder==4.4.1 (from apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_AppBuilder-4.4.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting flask-login>=0.6.2 (from apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_Login-0.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting apispec<7,>=6.0.0 (from apispec[yaml]<7,>=6.0.0->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached apispec-6.6.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.4.6)
# Requirement already satisfied: click<9,>=8 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (8.1.7)
# Collecting email-validator>=1.0.5 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached email_validator-2.1.1-py3-none-any.whl.metadata (26 kB)
# Collecting Flask-Babel<3,>=1 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_Babel-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting Flask-Limiter<4,>3 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_Limiter-3.6.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_JWT_Extended-4.6.0-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting marshmallow<4,>=3.18.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached marshmallow-3.21.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting marshmallow-sqlalchemy<0.29.0,>=0.22.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached marshmallow_sqlalchemy-0.28.2-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting prison<1.0.0,>=0.2.1 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached prison-0.2.1-py2.py3-none-any.whl.metadata (973 bytes)
# Collecting sqlalchemy-utils<1,>=0.32.21 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached SQLAlchemy_Utils-0.41.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting WTForms<4 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached wtforms-3.1.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting clickclick<21,>=1.2 (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow)
#   Using cached clickclick-20.10.2-py2.py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow) (6.0.1)
# Collecting inflection<0.6,>=0.3.1 (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow)
#   Using cached inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting werkzeug<3,>=2.0 (from apache-airflow)
#   Using cached Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting pytz>2021.1 (from croniter>=2.0.2->apache-airflow)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from cryptography>=39.0.0->apache-airflow) (1.16.0)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.13->apache-airflow)
#   Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting cachelib<0.10.0,>=0.9.0 (from flask-caching>=1.5.0->apache-airflow)
#   Using cached cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->apache-airflow)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->apache-airflow)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->apache-airflow)
#   Using cached rpds_py-0.18.1-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Collecting uc-micro-py (from linkify-it-py>=2.0.0->apache-airflow)
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.2)
# Collecting wirerope>=0.4.7 (from methodtools>=0.4.7->apache-airflow)
#   Using cached wirerope-0.4.7-py3-none-any.whl
# Collecting importlib-metadata<=7.0,>=6.0 (from opentelemetry-api>=1.15.0->apache-airflow)
#   Using cached importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow) (2024.1)
# Collecting time-machine>=2.6.0 (from pendulum<4.0,>=2.1.2->apache-airflow)
#   Using cached time_machine-2.14.1-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting docutils (from python-daemon>=3.0.0->apache-airflow)
#   Using cached docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: setuptools>=62.4.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from python-daemon>=3.0.0->apache-airflow) (69.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Collecting text-unidecode>=1.3 (from python-slugify>=5.0->apache-airflow)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (2024.2.2)
# Collecting greenlet!=0.4.17 (from sqlalchemy<2.0,>=1.4.36->apache-airflow)
#   Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting more-itertools>=9.0.0 (from apache-airflow-providers-common-sql->apache-airflow)
#   Using cached more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting sqlparse>=0.4.2 (from apache-airflow-providers-common-sql->apache-airflow)
#   Using cached sqlparse-0.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: aiohttp>=3.9.2 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (3.9.5)
# Collecting requests_toolbelt (from apache-airflow-providers-http->apache-airflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting anyio (from httpx->apache-airflow)
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx->apache-airflow)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting sniffio (from httpx->apache-airflow)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->apache-airflow)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.24.0 (from opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.24.0 (from opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.24.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (1.63.0)
# Collecting grpcio<2.0.0,>=1.0.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached grpcio-1.63.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_proto-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk~=1.24.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_sdk-1.24.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from opentelemetry-proto==1.24.0->opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (4.25.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.9.4)
# Requirement already satisfied: pycparser in c:\users\gladi\onedrive\desktop\mlops a3\venv_name\lib\site-packages (from cffi>=1.12->cryptography>=39.0.0->apache-airflow) (2.22)
# Collecting zipp>=0.5 (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.15.0->apache-airflow)
#   Using cached zipp-3.18.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=1.0.5->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting Babel>=2.3 (from Flask-Babel<3,>=1->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Babel-2.15.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting limits>=2.8 (from Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached limits-3.11.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting ordered-set<5,>4 (from Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-sdk~=1.24.0->opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting importlib-resources>=1.3 (from limits>=2.8->Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Using cached apache_airflow-2.9.1-py3-none-any.whl (13.3 MB)
# Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Using cached apache_airflow_providers_fab-1.1.0-py3-none-any.whl (78 kB)
# Using cached Flask_AppBuilder-4.4.1-py3-none-any.whl (2.2 MB)
# Using cached argcomplete-3.3.0-py3-none-any.whl (42 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Using cached ConfigUpdater-3.2-py2.py3-none-any.whl (34 kB)
# Using cached connexion-2.14.2-py2.py3-none-any.whl (95 kB)
# Using cached cron_descriptor-1.4.3-py3-none-any.whl (49 kB)
# Using cached croniter-2.0.5-py2.py3-none-any.whl (20 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached Flask-2.2.5-py3-none-any.whl (101 kB)
# Using cached Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Using cached flask_session-0.5.0-py3-none-any.whl (7.2 kB)
# Using cached flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Using cached google_re2-1.1.20240501-1-cp312-cp312-win_amd64.whl (480 kB)
# Using cached gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Using cached lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached marshmallow_oneofschema-3.1.1-py3-none-any.whl (5.7 kB)
# Using cached mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
# Using cached opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
# Using cached pendulum-3.0.0-cp312-none-win_amd64.whl (293 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Using cached python_daemon-3.0.1-py3-none-any.whl (31 kB)
# Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached rich_argparse-1.4.0-py3-none-any.whl (19 kB)
# Using cached setproctitle-1.3.3-cp312-cp312-win_amd64.whl (11 kB)
# Using cached SQLAlchemy-1.4.52-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached SQLAlchemy_JSONField-1.0.2-py3-none-any.whl (10 kB)
# Using cached tenacity-8.3.0-py3-none-any.whl (25 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached universal_pathlib-0.2.2-py3-none-any.whl (46 kB)
# Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Using cached apache_airflow_providers_common_io-1.3.1-py3-none-any.whl (16 kB)
# Using cached apache_airflow_providers_common_sql-1.13.0-py3-none-any.whl (46 kB)
# Using cached apache_airflow_providers_ftp-3.9.0-py3-none-any.whl (19 kB)
# Using cached apache_airflow_providers_http-4.11.0-py3-none-any.whl (27 kB)
# Using cached apache_airflow_providers_imap-3.6.0-py3-none-any.whl (17 kB)
# Using cached apache_airflow_providers_smtp-1.7.0-py3-none-any.whl (22 kB)
# Using cached apache_airflow_providers_sqlite-3.8.0-py3-none-any.whl (13 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached lazy_object_proxy-1.10.0-cp312-cp312-win_amd64.whl (27 kB)
# Using cached opentelemetry_exporter_otlp-1.24.0-py3-none-any.whl (7.0 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.24.0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
# Using cached cachelib-0.9.0-py3-none-any.whl (15 kB)
# Using cached clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Using cached Flask_Login-0.6.3-py3-none-any.whl (17 kB)
# Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
# Using cached importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached marshmallow-3.21.2-py3-none-any.whl (49 kB)
# Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.18.1-cp312-none-win_amd64.whl (209 kB)
# Using cached sqlparse-0.5.0-py3-none-any.whl (43 kB)
# Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached time_machine-2.14.1-cp312-cp312-win_amd64.whl (19 kB)
# Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached wtforms-3.1.2-py3-none-any.whl (145 kB)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached docutils-0.21.2-py3-none-any.whl (587 kB)
# Using cached Mako-1.3.3-py3-none-any.whl (78 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Using cached apispec-6.6.1-py3-none-any.whl (30 kB)
# Using cached email_validator-2.1.1-py3-none-any.whl (30 kB)
# Using cached Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Using cached Flask_JWT_Extended-4.6.0-py2.py3-none-any.whl (22 kB)
# Using cached Flask_Limiter-3.6.0-py3-none-any.whl (28 kB)
# Using cached Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Using cached grpcio-1.63.0-cp312-cp312-win_amd64.whl (3.9 MB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached marshmallow_sqlalchemy-0.28.2-py2.py3-none-any.whl (16 kB)
# Using cached opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
# Using cached opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Using cached prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Using cached SQLAlchemy_Utils-0.41.2-py3-none-any.whl (93 kB)
# Using cached zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Using cached Babel-2.15.0-py3-none-any.whl (9.6 MB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Using cached limits-3.11.0-py3-none-any.whl (45 kB)
# Using cached ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Building wheels for collected packages: methodtools
#   Building wheel for methodtools (pyproject.toml): started
#   Building wheel for methodtools (pyproject.toml): finished with status 'done'
#   Created wheel for methodtools: filename=methodtools-0.4.7-py3-none-any.whl size=3987 sha256=38bcbf41098cf34ca9c00c1d63404f78c00dca9ba35d863c1a3ecb0717cd1373
#   Stored in directory: c:\users\gladi\appdata\local\pip\cache\wheels\e5\a2\5a\a50b2d925f835b0a2bb09cdf79d224296dcab5ffed13f1394a
# Successfully built methodtools
# Installing collected packages: unicodecsv, text-unidecode, pytz, lockfile, cron-descriptor, zipp, wrapt, wirerope, universal-pathlib, uc-micro-py, termcolor, tenacity, sqlparse, sniffio, setproctitle, rpds-py, rfc3339-validator, python-slugify, pyjwt, prison, pluggy, ordered-set, opentelemetry-semantic-conventions, opentelemetry-proto, more-itertools, marshmallow, markupsafe, lazy-object-proxy, itsdangerous, inflection, importlib-resources, h11, gunicorn, grpcio, greenlet, google-re2, docutils, dnspython, dill, configupdater, colorlog, cachelib, blinker, Babel, asgiref, argcomplete, apispec, WTForms, werkzeug, time-machine, sqlalchemy, requests_toolbelt, referencing, python-daemon, opentelemetry-exporter-otlp-proto-common, methodtools, mdit-py-plugins, marshmallow-oneofschema, Mako, linkify-it-py, jinja2, importlib-metadata, httpcore, email-validator, deprecated, croniter, clickclick, anyio, sqlalchemy-utils, sqlalchemy-jsonfield, rich-argparse, python-nvd3, pendulum, opentelemetry-api, marshmallow-sqlalchemy, limits, jsonschema-specifications, httpx, flask, alembic, opentelemetry-sdk, jsonschema, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-Limiter, Flask-JWT-Extended, flask-caching, Flask-Babel, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, flask-appbuilder, connexion, opentelemetry-exporter-otlp, apache-airflow-providers-common-sql, apache-airflow-providers-sqlite, apache-airflow-providers-smtp, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, apache-airflow-providers-fab, apache-airflow-providers-common-io, apache-airflow
# Successfully installed Babel-2.15.0 Flask-Babel-2.0.0 Flask-JWT-Extended-4.6.0 Flask-Limiter-3.6.0 Flask-SQLAlchemy-2.5.1 Mako-1.3.3 WTForms-3.1.2 alembic-1.13.1 anyio-4.3.0 apache-airflow-2.9.1 apache-airflow-providers-common-io-1.3.1 apache-airflow-providers-common-sql-1.13.0 apache-airflow-providers-fab-1.1.0 apache-airflow-providers-ftp-3.9.0 apache-airflow-providers-http-4.11.0 apache-airflow-providers-imap-3.6.0 apache-airflow-providers-smtp-1.7.0 apache-airflow-providers-sqlite-3.8.0 apispec-6.6.1 argcomplete-3.3.0 asgiref-3.8.1 blinker-1.8.2 cachelib-0.9.0 clickclick-20.10.2 colorlog-4.8.0 configupdater-3.2 connexion-2.14.2 cron-descriptor-1.4.3 croniter-2.0.5 deprecated-1.2.14 dill-0.3.8 dnspython-2.6.1 docutils-0.21.2 email-validator-2.1.1 flask-2.2.5 flask-appbuilder-4.4.1 flask-caching-2.3.0 flask-login-0.6.3 flask-session-0.5.0 flask-wtf-1.2.1 google-re2-1.1.20240501 greenlet-3.0.3 grpcio-1.63.0 gunicorn-22.0.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 importlib-metadata-7.0.0 importlib-resources-6.4.0 inflection-0.5.1 itsdangerous-2.2.0 jinja2-3.1.4 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 limits-3.11.0 linkify-it-py-2.0.3 lockfile-0.12.2 markupsafe-2.1.5 marshmallow-3.21.2 marshmallow-oneofschema-3.1.1 marshmallow-sqlalchemy-0.28.2 mdit-py-plugins-0.4.0 methodtools-0.4.7 more-itertools-10.2.0 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-exporter-otlp-proto-http-1.24.0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 ordered-set-4.1.0 pendulum-3.0.0 pluggy-1.5.0 prison-0.2.1 pyjwt-2.8.0 python-daemon-3.0.1 python-nvd3-0.16.0 python-slugify-8.0.4 pytz-2024.1 referencing-0.35.1 requests_toolbelt-1.0.0 rfc3339-validator-0.1.4 rich-argparse-1.4.0 rpds-py-0.18.1 setproctitle-1.3.3 sniffio-1.3.1 sqlalchemy-1.4.52 sqlalchemy-jsonfield-1.0.2 sqlalchemy-utils-0.41.2 sqlparse-0.5.0 tenacity-8.3.0 termcolor-2.4.0 text-unidecode-1.3 time-machine-2.14.1 uc-micro-py-1.0.3 unicodecsv-0.14.1 universal-pathlib-0.2.2 werkzeug-2.2.3 wirerope-0.4.7 wrapt-1.16.0 zipp-3.18.1

# %%
from datetime import datetime

from airflow import DAG
from airflow.operators.python_operator import PythonOperator
from my_module import extract_data, clean_data, save_to_csv, transform

default_args = {
    'owner': 'airflow',
    'start_date': datetime(2024, 5, 12),
    'retries': 3,
}

with DAG('mlops_dag', default_args=default_args, schedule_interval='@daily') as dag:
    
    def extract_transform_load():
        extract_data(['https://www.dawn.com/', 'https://www.bbc.com/'])
        clean_data('dawn.csv')
        transform('dawn.csv', 'BBCinfoXML.csv', 'cleaned.csv')
        save_to_csv('cleaned.csv')
    
    run_etl = PythonOperator(
        task_id='run_etl',
        python_callable=extract_transform_load
    )
    
    run_etl
# Out:
# c:\Users\gladi\OneDrive\Desktop\mlops a3\venv_name\Lib\site-packages\airflow\__init__.py:35 RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
# [2024-05-12T15:47:43.658+0500] {logging_config.py:71} ERROR - Unable to load the config, contains a configuration error.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File C:\Python312\Lib\logging\config.py:105, in _resolve(name)
#     104 try:
# --> 105     found = getattr(found, n)
#     106 except AttributeError:
#
# AttributeError: partially initialized module 'airflow' has no attribute 'utils' (most likely due to a circular import)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File C:\Python312\Lib\logging\config.py:560, in DictConfigurator.configure(self)
#     559 try:
# --> 560     formatters[name] = self.configure_formatter(
#     561                                         formatters[name])
#     562 except Exception as e:
#
# File C:\Python312\Lib\logging\config.py:693, in DictConfigurator.configure_formatter(self, config)
#     692 else:
# --> 693     c = _resolve(cname)
#     695 kwargs  = {}
#
# File C:\Python312\Lib\logging\config.py:108, in _resolve(name)
#     107         __import__(used)
# --> 108         found = getattr(found, n)
#     109 return found
#
# AttributeError: partially initialized module 'airflow' has no attribute 'utils' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 from datetime import datetime
# ----> 3 from airflow import DAG
#       4 from airflow.operators.python_operator import PythonOperator
#       5 from my_module import extract_data, clean_data, save_to_csv, transform
#
# File c:\Users\gladi\OneDrive\Desktop\mlops a3\venv_name\Lib\site-packages\airflow\__init__.py:73
#      67 # Perform side-effects unless someone has explicitly opted out before import
#      68 # WARNING: DO NOT USE THIS UNLESS YOU REALLY KNOW WHAT YOU'RE DOING.
#      69 # This environment variable prevents proper initialization, and things like
#      70 # configs, logging, the ORM, etc. will be broken. It is only useful if you only
#      71 # access certain trivial constants and free functions (e.g. `__version__`).
#      72 if not os.environ.get("_AIRFLOW__AS_LIBRARY", None):
# ---> 73     settings.initialize()
#      75 # Things to lazy import in form {local_name: ('target_module', 'target_name', 'deprecated')}
#      76 __lazy_imports: dict[str, tuple[str, str, bool]] = {
#      77     "DAG": (".models.dag", "DAG", False),
#      78     "Dataset": (".datasets", "Dataset", False),
#    (...)
#      82     "AirflowException": (".exceptions", "AirflowException", True),
#      83 }
#
# File c:\Users\gladi\OneDrive\Desktop\mlops a3\venv_name\Lib\site-packages\airflow\settings.py:531, in initialize()
#     529 import_local_settings()
#     530 global LOGGING_CLASS_PATH
# --> 531 LOGGING_CLASS_PATH = configure_logging()
#     532 State.state_color.update(STATE_COLORS)
#     534 configure_adapters()
#
# File c:\Users\gladi\OneDrive\Desktop\mlops a3\venv_name\Lib\site-packages\airflow\logging_config.py:74, in configure_logging()
#      71     log.error("Unable to load the config, contains a configuration error.")
#      72     # When there is an error in the config, escalate the exception
#      73     # otherwise Airflow would silently fall back on the default config
# ---> 74     raise e
#      76 validate_logging_config(logging_config)
#      78 return logging_class_path
#
# File c:\Users\gladi\OneDrive\Desktop\mlops a3\venv_name\Lib\site-packages\airflow\logging_config.py:69, in configure_logging()
#      66             task_handler_config["filters"].append("mask_secrets")
#      68     # Try to init logging
# ---> 69     dictConfig(logging_config)
#      70 except (ValueError, KeyError) as e:
#      71     log.error("Unable to load the config, contains a configuration error.")
#
# File C:\Python312\Lib\logging\config.py:914, in dictConfig(config)
#     912 def dictConfig(config):
#     913     """Configure logging using a dictionary."""
# --> 914     dictConfigClass(config).configure()
#
# File C:\Python312\Lib\logging\config.py:563, in DictConfigurator.configure(self)
#     560         formatters[name] = self.configure_formatter(
#     561                                             formatters[name])
#     562     except Exception as e:
# --> 563         raise ValueError('Unable to configure '
#     564                          'formatter %r' % name) from e
#     565 # Next, do filters - they don't refer to anything else, either
#     566 filters = config.get('filters', EMPTY_DICT)
#
# ValueError: Unable to configure formatter 'airflow'

# %% [markdown]
# export GOOGLE_APPLICATION_CREDENTIALS="C:\\Users\\gladi\\OneDrive\\Desktop\\mlops a3\\turing-reach-413612-f3ac0771dced.json"
